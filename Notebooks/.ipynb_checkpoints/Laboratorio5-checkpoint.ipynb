# %% [markdown]
# # Datos Sintéticos
# # Utilización de la libreria FAKER
# *Autor: Sandra Yamileth Jimenez Asis*

# %%
import pandas as pd
import numpy as np
import random

# %%
from faker import Faker

# %%
# Creamos una instancia de Faker
fake = Faker("es_MX")

# %%
# Generamos datos sinteticos a datos falsos 
datos = []
for  i in range(100):
        datos. append(
            {
                "id_usuario": i + 1,
                "nombre": fake.name(),
                "correo": fake.email(),
                "edad": random.randint(18,65),
                "seguidores": random.randint(50,5000),
                "plataforma": random.choice(["TikTok","Instagram","YouTube"])
            }
        )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                          nombre                       correo  \
# 0            1                Sr. Hugo Peralta     alemanmanuel@example.org
# 1            2      Victoria Elvira de la Rosa     roblesjacobo@example.net
# 2            3  Silvano Genaro Toledo Quiñones           aldo15@example.org
# 3            4               Sr. Homero Arenas           xponce@example.com
# 4            5           Lic. Yuridia Tijerina         vbonilla@example.com
# ..         ...                             ...                          ...
# 95          96               Noemí Luz Carreón  marisolceballos@example.net
# 96          97                 Joaquín Peralta      anabelrolon@example.com
# 97          98        Luis Lucas Jimínez Yáñez   almanzaaraceli@example.org
# 98          99                    Alvaro Ortiz     cepedaamador@example.com
# 99         100    Elvia Yolanda Nazario Galván         tsolorio@example.com
#
#     edad  seguidores plataforma
# 0     36        1497     TikTok
# 1     45        3065  Instagram
# 2     27        3037     TikTok
# 3     20        3204  Instagram
# 4     41        1108  Instagram
# ..   ...         ...        ...
# 95    62         386    YouTube
# 96    50        4045     TikTok
# 97    44        1380  Instagram
# 98    60         872     TikTok
# 99    46        1553  Instagram
#
# [100 rows x 6 columns]

# %% [raw]
# dfInfluencer.info()

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   42.940000  2328.200000
# std     29.011492   13.720014  1376.778358
# min      1.000000   18.000000    96.000000
# 25%     25.750000   30.000000  1106.750000
# 50%     50.500000   44.000000  2233.000000
# 75%     75.250000   54.000000  3362.750000
# max    100.000000   65.000000  4972.000000

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario            nombre                    correo        edad  \
# count   100.000000               100                       100  100.000000
# unique         NaN               100                       100         NaN
# top            NaN  Sr. Hugo Peralta  alemanmanuel@example.org         NaN
# freq           NaN                 1                         1         NaN
# mean     50.500000               NaN                       NaN   42.940000
# std      29.011492               NaN                       NaN   13.720014
# min       1.000000               NaN                       NaN   18.000000
# 25%      25.750000               NaN                       NaN   30.000000
# 50%      50.500000               NaN                       NaN   44.000000
# 75%      75.250000               NaN                       NaN   54.000000
# max     100.000000               NaN                       NaN   65.000000
#
#          seguidores plataforma
# count    100.000000        100
# unique          NaN          3
# top             NaN  Instagram
# freq            NaN         40
# mean    2328.200000        NaN
# std     1376.778358        NaN
# min       96.000000        NaN
# 25%     1106.750000        NaN
# 50%     2233.000000        NaN
# 75%     3362.750000        NaN
# max     4972.000000        NaN

# %%
# Graficar
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Graficamos como se generaron las edades 
plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins=10)
plt.title("Distribución de edades")
plt.show()

# %%
# Graficamos la cantidad de usuarios por plataforma 
plt.figure(figsize = (8,4))
sns.countplot(x="plataforma", data = dfInfluencer)
plt.title("Cantidada de usuarios por plataforma")
plt.show()
